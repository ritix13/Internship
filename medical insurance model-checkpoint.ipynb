# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
a=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')
a
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
a.shape
# Out:
# (1338, 7)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
a.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
a.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(a['age'])
plt.title('age distribution')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='sex',data=a)
plt.title('sex distribution')
plt.show()

# %%
a['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.distplot(a['bmi'])
plt.title('bmi distribution')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='children',data=a)
plt.title('children distribution')
plt.show()

# %%
a['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='smoker',data=a)
plt.title('smoker distribution')
plt.show()

# %%
a['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='region',data=a)
plt.title('region distribution')
plt.show()

# %%
a['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.distplot(a['charges'])
plt.title('charges distribution')
plt.show()

# %%
a.replace({'sex':{'male':1,'female':2}},inplace=True)

# %%
a.replace({'smoker':{'yes':1,'no':2}},inplace=True)

# %%
a.replace({'region':{'southeast':1,'southwest':2,'northwest':3,'northeast':4}},inplace=True)

# %%
a
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    2  27.900         0       1       2  16884.92400
# 1      18    1  33.770         1       2       1   1725.55230
# 2      28    1  33.000         3       2       1   4449.46200
# 3      33    1  22.705         0       2       3  21984.47061
# 4      32    1  28.880         0       2       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       2       3  10600.54830
# 1334   18    2  31.920         0       2       4   2205.98080
# 1335   18    2  36.850         0       2       1   1629.83350
# 1336   21    2  25.800         0       2       2   2007.94500
# 1337   61    2  29.070         0       1       3  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=a.drop(columns='charges',axis=1)
y=a['charges']

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1
for column in x:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column)
        plt.ylabel('charges')
    plotnumber+=1
plt.show()

# %%
scaler=StandardScaler()     # when the data in dataset has different scale for that we have to maek the same scale , 
                             #for which we can use standardscalers
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.43876426,  1.0105187 , -0.45332   , -0.90861367, -1.97058663,
#         -0.40287427],
#        [-1.50996545, -0.98959079,  0.5096211 , -0.07876719,  0.5074631 ,
#         -1.28800691],
#        [-0.79795355, -0.98959079,  0.38330685,  1.58092576,  0.5074631 ,
#         -1.28800691],
#        ...,
#        [-1.50996545,  1.0105187 ,  1.0148781 , -0.90861367,  0.5074631 ,
#         -1.28800691],
#        [-1.29636188,  1.0105187 , -0.79781341, -0.90861367,  0.5074631 ,
#         -0.40287427],
#        [ 1.55168573,  1.0105187 , -0.26138796, -0.90861367, -1.97058663,
#          0.48225837]])

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2)

# %%
regression=LinearRegression()
regression.fit(x_train,y_train)    #model is trained
# Out:
# LinearRegression()

# %%
regression.score(x_train,y_train)
# Out:
# 0.7502234681317635

# %%
regression.score(x_test,y_test)
# Out:
# 0.7505625600466854
